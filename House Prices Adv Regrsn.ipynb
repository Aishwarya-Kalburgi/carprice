# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.pandas.set_option('display.max_columns',False)

# %%
dataset = pd. read_csv('train.csv');

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street  ... MiscVal MoSold YrSold SaleType SaleCondition SalePrice
# 0   1          60       RL         65.0     8450   Pave  ...       0      2   2008       WD        Normal    208500
# 1   2          20       RL         80.0     9600   Pave  ...       0      5   2007       WD        Normal    181500
# 2   3          60       RL         68.0    11250   Pave  ...       0      9   2008       WD        Normal    223500
# 3   4          70       RL         60.0     9550   Pave  ...       0      2   2006       WD       Abnorml    140000
# 4   5          60       RL         84.0    14260   Pave  ...       0     12   2008       WD        Normal    250000
#
# [5 rows x 81 columns]

# %%
print(dataset.shape)
# Out:
# (1460, 81)

# %% [markdown]
# # Data Analysis
#
# 1. Missimg values
# 2. Numerical variables
# 3. Distribution of numerical varibales
# 4. catagorical variables
# 5. Cardiability of catagorical variables
# 6. outliers
# 7. Relationship betweek dependent and independent features

# %% [markdown]
# ## Missing values

# %%
features_with_na=[features for features in dataset.columns if dataset[features].isnull().sum()>1]

# %%
for features in features_with_na:
    print(features, np.round(dataset[features].isnull().mean(),4),'% missing values')
# Out:
# LotFrontage 0.1774 % missing values
# Alley 0.9377 % missing values
# MasVnrType 0.0055 % missing values
# MasVnrArea 0.0055 % missing values
# BsmtQual 0.0253 % missing values
# BsmtCond 0.0253 % missing values
# BsmtExposure 0.026 % missing values
# BsmtFinType1 0.0253 % missing values
# BsmtFinType2 0.026 % missing values
# FireplaceQu 0.4726 % missing values
# GarageType 0.0555 % missing values
# GarageYrBlt 0.0555 % missing values
# GarageFinish 0.0555 % missing values
# GarageQual 0.0555 % missing values
# GarageCond 0.0555 % missing values
# PoolQC 0.9952 % missing values
# Fence 0.8075 % missing values
# MiscFeature 0.963 % missing values

# %%
for feature in features_with_na:
    data=dataset.copy()
    
    data[feature]=np.where(data[feature].isnull(),1,0)
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    
    plt.title(feature)  
    plt.show()

# %%
numerical_feature = [feature for feature in dataset.columns if dataset[feature].dtypes != 'O']

print(len(numerical_feature))

data[numerical_feature].head()
# Out:
# 38
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  ...  PoolArea  MiscVal  MoSold  YrSold  SalePrice
# 0   1          60         65.0     8450            7  ...         0        0       2    2008     208500
# 1   2          20         80.0     9600            6  ...         0        0       5    2007     181500
# 2   3          60         68.0    11250            7  ...         0        0       9    2008     223500
# 3   4          70         60.0     9550            7  ...         0        0       2    2006     140000
# 4   5          60         84.0    14260            8  ...         0        0      12    2008     250000
#
# [5 rows x 38 columns]

# %%
year_feature=[feature for feature in dataset.columns if 'Yr' in feature or 'Year' in feature]

print(year_feature)
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
for feature in year_feature:
    if feature != 'YrSold':
        data=dataset.copy()
        
        data[feature]=data['YrSold']-data[feature]
        
        plt.scatter(data[feature], data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel ('SalePrice')
        plt.show()

# %%
discrete_features = [feature for feature in numerical_feature if len(dataset[feature].unique())<25 and feature not in year_feature+['Id']]
len(discrete_features)
# Out:
# 17

# %%
dataset[discrete_features].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  ...  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# 0          60            7            5             0             1  ...           2          0         0        0       2
# 1          20            6            8             0             0  ...           2          0         0        0       5
# 2          60            7            5             0             1  ...           2          0         0        0       9
# 3          70            7            5             0             1  ...           3          0         0        0       2
# 4          60            8            5             0             1  ...           3          0         0        0      12
#
# [5 rows x 17 columns]

# %%
for feature in discrete_features:
    data=dataset.copy()
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Saleprice')
    plt.show()

# %%
continous_features=[feature for feature in numerical_feature if feature not in discrete_features+['Id']]
continous_features
# Out:
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'YrSold',
#  'SalePrice']

# %%
for feature in continous_features:
    data=dataset.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel('Count')
    plt.title(feature)
    plt.show()

# %%
for feature in continous_features:
    data=dataset.copy()
    
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data['SalePrice']=np.log(data['SalePrice'])
        plt.scatter(data[feature],data['SalePrice'] )
        plt.xlabel(feature)
        plt.ylabel('Saleprice')
        plt.show()

# %% [markdown]
# ## Outliers

# %%
for feature in continous_features:
    data=dataset.copy()
    
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %%
categorical_features=[feature for feature in dataset.columns if data[feature].dtypes=='O']
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
for feature in categorical_features:
    print('{} -> {}'.format(feature, len(dataset[feature].unique())))
# Out:
# MSZoning -> 5
# Street -> 2
# Alley -> 3
# LotShape -> 4
# LandContour -> 4
# Utilities -> 2
# LotConfig -> 5
# LandSlope -> 3
# Neighborhood -> 25
# Condition1 -> 9
# Condition2 -> 8
# BldgType -> 5
# HouseStyle -> 8
# RoofStyle -> 6
# RoofMatl -> 8
# Exterior1st -> 15
# Exterior2nd -> 16
# MasVnrType -> 5
# ExterQual -> 4
# ExterCond -> 5
# Foundation -> 6
# BsmtQual -> 5
# BsmtCond -> 5
# BsmtExposure -> 5
# BsmtFinType1 -> 7
# BsmtFinType2 -> 7
# Heating -> 6
# HeatingQC -> 5
# CentralAir -> 2
# Electrical -> 6
# KitchenQual -> 4
# Functional -> 7
# FireplaceQu -> 6
# GarageType -> 7
# GarageFinish -> 4
# GarageQual -> 6
# GarageCond -> 6
# PavedDrive -> 3
# PoolQC -> 4
# Fence -> 5
# MiscFeature -> 5
# SaleType -> 9
# SaleCondition -> 6

# %%
for feature in categorical_features:
    data=dataset.copy()
    
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Saleprice')
    plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(dataset,dataset['SalePrice'],test_size=0.1,random_state=0)

# %% [markdown]
# ## missing values

# %%
# Missing categorical feature handling
data=dataset.copy()
feature_withNa=[feature for feature in dataset.columns if data[feature].isnull().sum()>1 and data[feature].dtypes == 'O']
print(feature_withNa,np.around(data[feature_withNa].isnull().mean(), 4))
# Out:
# ['Alley', 'MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature'] Alley           0.9377
# MasVnrType      0.0055
# BsmtQual        0.0253
# BsmtCond        0.0253
# BsmtExposure    0.0260
# BsmtFinType1    0.0253
# BsmtFinType2    0.0260
# FireplaceQu     0.4726
# GarageType      0.0555
# GarageFinish    0.0555
# GarageQual      0.0555
# GarageCond      0.0555
# PoolQC          0.9952
# Fence           0.8075
# MiscFeature     0.9630
# dtype: float64

# %%
def filling_na(dataset,feature_withNa):
    data=dataset.copy()
    
    data[feature_withNa]=data[feature_withNa].fillna('Missing')
    return data

dataset=filling_na(dataset,feature_withNa)
dataset[feature_withNa].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
# handling numerical missing values
feature_withNull=[feature for feature in dataset.columns if data[feature].isnull().sum()>1 and data[feature].dtypes != 'O']
print(feature_withNull,np.around(data[feature_withNull].isnull().mean(), 4))
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt'] LotFrontage    0.1774
# MasVnrArea     0.0055
# GarageYrBlt    0.0555
# dtype: float64

# %%
for feature in feature_withNull:
    median=dataset[feature].median()
    dataset[feature+'nan']=np.where(dataset[feature].isnull(),1,0)
    dataset[feature].fillna(median,inplace=True)  
    
dataset[feature_withNull].isnull().sum()
# Out:
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
dataset.head(25)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  ...  SalePrice LotFrontagenan MasVnrAreanan GarageYrBltnan
# 0    1          60       RL         65.0  ...     208500              0             0              0
# 1    2          20       RL         80.0  ...     181500              0             0              0
# 2    3          60       RL         68.0  ...     223500              0             0              0
# 3    4          70       RL         60.0  ...     140000              0             0              0
# 4    5          60       RL         84.0  ...     250000              0             0              0
# 5    6          50       RL         85.0  ...     143000              0             0              0
# 6    7          20       RL         75.0  ...     307000              0             0              0
# 7    8          60       RL         69.0  ...     200000              1             0              0
# ...

# %%
year_feature=[feature for feature in dataset.columns if 'Yr' in feature or 'Year' in feature]

print(year_feature)
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold', 'GarageYrBltnan']

# %%
for feature in ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt']:
    dataset[feature]=dataset['YrSold']-dataset[feature]

# %%
dataset[['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt  YrSold
# 0          5             5          5.0    2008
# 1         31            31         31.0    2007
# 2          7             6          7.0    2008
# 3         91            36          8.0    2006
# 4          8             8          8.0    2008

# %%
num_features =['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    dataset[feature]=np.log(dataset[feature])

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  ...  SalePrice LotFrontagenan MasVnrAreanan GarageYrBltnan
# 0   1          60       RL     4.174387  ...  12.247694              0             0              0
# 1   2          20       RL     4.382027  ...  12.109011              0             0              0
# 2   3          60       RL     4.219508  ...  12.317167              0             0              0
# 3   4          70       RL     4.094345  ...  11.849398              0             0              0
# 4   5          60       RL     4.430817  ...  12.429216              0             0              0
#
# [5 rows x 84 columns]

# %%
for feature in categorical_features:
    temp = dataset.groupby(feature)['SalePrice'].count()/len(dataset)
    tempd=temp[temp>0.01].index
    dataset[feature]=np.where(dataset[feature].isin(tempd), dataset[feature], 'Rare_var')

# %%
dataset.head(50)
# Out:
#     Id  MSSubClass  MSZoning  LotFrontage  ...  SalePrice LotFrontagenan MasVnrAreanan GarageYrBltnan
# 0    1          60        RL     4.174387  ...  12.247694              0             0              0
# 1    2          20        RL     4.382027  ...  12.109011              0             0              0
# 2    3          60        RL     4.219508  ...  12.317167              0             0              0
# 3    4          70        RL     4.094345  ...  11.849398              0             0              0
# 4    5          60        RL     4.430817  ...  12.429216              0             0              0
# 5    6          50        RL     4.442651  ...  11.870600              0             0              0
# 6    7          20        RL     4.317488  ...  12.634603              0             0              0
# 7    8          60        RL     4.234107  ...  12.206073              1             0              0
# ...

# %%
dataset.groupby(['MSZoning'])['SalePrice'].mean()
# Out:
# MSZoning
# FV          12.246616
# RH          11.749840
# RL          12.085885
# RM          11.692893
# Rare_var    11.118259
# Name: SalePrice, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

for feature in categorical_features:
    le=LabelEncoder()
    dataset[feature]=le.fit_transform(dataset[feature])

# %%
dataset.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  ...  SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1          60         2     4.174387  ...  12.247694               0              0               0
# 1   2          20         2     4.382027  ...  12.109011               0              0               0
# 2   3          60         2     4.219508  ...  12.317167               0              0               0
# 3   4          70         2     4.094345  ...  11.849398               0              0               0
# 4   5          60         2     4.430817  ...  12.429216               0              0               0
#
# [5 rows x 84 columns]

# %% [markdown]
# ## feature scalaing

# %%
features_sc=[feature for feature in dataset.columns if feature not in ['Id', 'SalePrice']]

from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
scalar.fit(dataset[features_sc])
# Out:
# MinMaxScaler()

# %%
data=pd.concat([dataset[['Id', 'SalePrice']].reset_index(drop=True),
              pd.DataFrame(scalar.transform(dataset[features_sc]),columns=features_sc)], axis=1)

# %%
data.head()
# Out:
#    Id  SalePrice  MSSubClass  MSZoning  ...  SaleCondition  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1  12.247694    0.235294       0.5  ...            0.5             0.0            0.0             0.0
# 1   2  12.109011    0.000000       0.5  ...            0.5             0.0            0.0             0.0
# 2   3  12.317167    0.235294       0.5  ...            0.5             0.0            0.0             0.0
# 3   4  11.849398    0.294118       0.5  ...            0.0             0.0            0.0             0.0
# 4   5  12.429216    0.235294       0.5  ...            0.5             0.0            0.0             0.0
#
# [5 rows x 84 columns]

# %%
data.to_csv('x_train.csv',index=False)

# %%
# Lasso and SelectFromModel are used to do Feature selection
